# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, Normalizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.utils import resample
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.regularizers import l2
from tensorflow.keras.callbacks import EarlyStopping
import spacy

# %%
df = pd.read_csv("diario_emociones.csv")

# Split inicial estratificado (80% entrenamiento, 20% test)
X_temp, X_test, y_temp, y_test = train_test_split(
    df["texto"],        # Features: solo columna de texto
    df["emocion"],      # Target: emociones
    test_size=0.2,
    stratify=df["emocion"],
    random_state=42
)

# Crear DataFrame para balanceo
train_df = pd.DataFrame({
    "texto": X_temp,
    "emocion": y_temp
})

# %%
balanced_dfs = []
for emocion in train_df["emocion"].unique():
    subset = train_df[train_df["emocion"] == emocion]
    balanced_dfs.append(
        resample(subset,
               replace=True,
               n_samples=500,
               random_state=42)
    )
    
train_df_balanced = pd.concat(balanced_dfs, ignore_index=True)

# Separar features y target balanceados
X_train = train_df_balanced["texto"]
y_train = train_df_balanced["emocion"]

# %%
nlp = spacy.load("es_core_news_sm")

def limpiar_texto(texto):
    doc = nlp(texto.lower())
    tokens = []
    for token in doc:
        if not token.is_stop and token.is_alpha:
            lemma = token.lemma_.strip()
            # Manejar signos importantes
            if lemma in ["¡", "!"]:
                tokens.append("EXCLAMACION")
            elif lemma in ["¿", "?"]:
                tokens.append("PREGUNTA")
            else:
                tokens.append(lemma)
    return " ".join(tokens)

# Aplicar limpieza
X_train_limpio = X_train.apply(limpiar_texto)
X_test_limpio = X_test.apply(limpiar_texto)

# %%
vectorizer = TfidfVectorizer(
    max_features=15000,
    ngram_range=(1, 3),
    min_df=2,
    max_df=0.75,
    stop_words=["de", "la", "que", "y", "en"]  # Añade tus stopwords
)

X_train_vec = vectorizer.fit_transform(X_train_limpio)
X_test_vec = vectorizer.transform(X_test_limpio)

# %%
normalizer = Normalizer(norm='l2')
X_train = normalizer.fit_transform(X_train_vec.toarray())
X_test = normalizer.transform(X_test_vec.toarray())

# %%
label_encoder = LabelEncoder()
y_train_enc = label_encoder.fit_transform(y_train)
y_test_enc = label_encoder.transform(y_test)  # Usamos y_test original

# %%
X_train_final, X_val, y_train_final, y_val = train_test_split(
    X_train, 
    y_train_enc,
    test_size=0.2,
    stratify=y_train_enc,
    random_state=42
)

# %%
model = Sequential()
model.add(Dense(
    512,
    activation='relu',
    input_shape=(X_train.shape[1],),
    kernel_regularizer=l2(0.005)
))
model.add(Dropout(0.4))
model.add(Dense(
    256,
    activation='relu',
    kernel_regularizer=l2(0.003))
)
model.add(Dropout(0.3))
model.add(Dense(
    len(label_encoder.classes_),
    activation='softmax'
))

model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# C:\Users\walte\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
early_stop = EarlyStopping(
    monitor='val_loss',
    patience=7,
    restore_best_weights=True,
    min_delta=0.001
)

history = model.fit(
    X_train_final, y_train_final,
    batch_size=128,
    epochs=200,
    validation_data=(X_val, y_val),
    callbacks=[early_stop],
    verbose=2
)
# Out:
# Epoch 1/200
# 16/16 - 2s - 147ms/step - accuracy: 0.6265 - loss: 4.5876 - val_accuracy: 0.9780 - val_loss: 3.5250
# Epoch 2/200
# 16/16 - 0s - 10ms/step - accuracy: 0.9855 - loss: 2.7425 - val_accuracy: 1.0000 - val_loss: 1.8157
# Epoch 3/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 1.3211 - val_accuracy: 1.0000 - val_loss: 0.9437
# Epoch 4/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.7874 - val_accuracy: 1.0000 - val_loss: 0.6123
# Epoch 5/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.5238 - val_accuracy: 1.0000 - val_loss: 0.4317
# Epoch 6/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.3946 - val_accuracy: 1.0000 - val_loss: 0.3429
# Epoch 7/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.3258 - val_accuracy: 1.0000 - val_loss: 0.2950
# Epoch 8/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.2867 - val_accuracy: 1.0000 - val_loss: 0.2644
# Epoch 9/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.2615 - val_accuracy: 1.0000 - val_loss: 0.2446
# Epoch 10/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.2444 - val_accuracy: 1.0000 - val_loss: 0.2310
# Epoch 11/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.2333 - val_accuracy: 1.0000 - val_loss: 0.2197
# Epoch 12/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.2235 - val_accuracy: 1.0000 - val_loss: 0.2117
# Epoch 13/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.2154 - val_accuracy: 1.0000 - val_loss: 0.2042
# Epoch 14/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.2071 - val_accuracy: 1.0000 - val_loss: 0.1980
# Epoch 15/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.2012 - val_accuracy: 1.0000 - val_loss: 0.1918
# Epoch 16/200
# 16/16 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.1962 - val_accuracy: 1.0000 - val_loss: 0.1869
# Epoch 17/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.1918 - val_accuracy: 1.0000 - val_loss: 0.1829
# Epoch 18/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.1869 - val_accuracy: 1.0000 - val_loss: 0.1787
# Epoch 19/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.1829 - val_accuracy: 1.0000 - val_loss: 0.1743
# Epoch 20/200
# 16/16 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.1779 - val_accuracy: 1.0000 - val_loss: 0.1702
# Epoch 21/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.1755 - val_accuracy: 1.0000 - val_loss: 0.1669
# Epoch 22/200
# 16/16 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.1714 - val_accuracy: 1.0000 - val_loss: 0.1633
# Epoch 23/200
# 16/16 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.1681 - val_accuracy: 1.0000 - val_loss: 0.1606
# Epoch 24/200
# 16/16 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.1651 - val_accuracy: 1.0000 - val_loss: 0.1588
# Epoch 25/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.1627 - val_accuracy: 1.0000 - val_loss: 0.1548
# Epoch 26/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.1588 - val_accuracy: 1.0000 - val_loss: 0.1517
# Epoch 27/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.1566 - val_accuracy: 1.0000 - val_loss: 0.1506
# Epoch 28/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.1533 - val_accuracy: 1.0000 - val_loss: 0.1483
# Epoch 29/200
# 16/16 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.1513 - val_accuracy: 1.0000 - val_loss: 0.1445
# Epoch 30/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.1489 - val_accuracy: 1.0000 - val_loss: 0.1430
# Epoch 31/200
# 16/16 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.1462 - val_accuracy: 1.0000 - val_loss: 0.1405
# Epoch 32/200
# 16/16 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.1445 - val_accuracy: 1.0000 - val_loss: 0.1388
# Epoch 33/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.1425 - val_accuracy: 1.0000 - val_loss: 0.1371
# Epoch 34/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.1406 - val_accuracy: 1.0000 - val_loss: 0.1348
# Epoch 35/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.1385 - val_accuracy: 1.0000 - val_loss: 0.1338
# Epoch 36/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.1373 - val_accuracy: 1.0000 - val_loss: 0.1322
# Epoch 37/200
# 16/16 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.1352 - val_accuracy: 1.0000 - val_loss: 0.1300
# Epoch 38/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.1337 - val_accuracy: 1.0000 - val_loss: 0.1283
# Epoch 39/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.1318 - val_accuracy: 1.0000 - val_loss: 0.1277
# Epoch 40/200
# 16/16 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.1308 - val_accuracy: 1.0000 - val_loss: 0.1253
# Epoch 41/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.1299 - val_accuracy: 1.0000 - val_loss: 0.1245
# Epoch 42/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.1279 - val_accuracy: 1.0000 - val_loss: 0.1229
# Epoch 43/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.1258 - val_accuracy: 1.0000 - val_loss: 0.1213
# Epoch 44/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.1251 - val_accuracy: 1.0000 - val_loss: 0.1207
# Epoch 45/200
# 16/16 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.1239 - val_accuracy: 1.0000 - val_loss: 0.1191
# Epoch 46/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.1226 - val_accuracy: 1.0000 - val_loss: 0.1183
# Epoch 47/200
# 16/16 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.1214 - val_accuracy: 1.0000 - val_loss: 0.1167
# Epoch 48/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.1201 - val_accuracy: 1.0000 - val_loss: 0.1158
# Epoch 49/200
# 16/16 - 0s - 18ms/step - accuracy: 1.0000 - loss: 0.1202 - val_accuracy: 1.0000 - val_loss: 0.1149
# Epoch 50/200
# 16/16 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.1179 - val_accuracy: 1.0000 - val_loss: 0.1131
# Epoch 51/200
# 16/16 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.1173 - val_accuracy: 1.0000 - val_loss: 0.1123
# Epoch 52/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.1160 - val_accuracy: 1.0000 - val_loss: 0.1120
# Epoch 53/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.1156 - val_accuracy: 1.0000 - val_loss: 0.1108
# Epoch 54/200
# 16/16 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.1137 - val_accuracy: 1.0000 - val_loss: 0.1098
# Epoch 55/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.1128 - val_accuracy: 1.0000 - val_loss: 0.1086
# Epoch 56/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.1125 - val_accuracy: 1.0000 - val_loss: 0.1080
# Epoch 57/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.1111 - val_accuracy: 1.0000 - val_loss: 0.1073
# Epoch 58/200
# 16/16 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1106 - val_accuracy: 1.0000 - val_loss: 0.1066
# Epoch 59/200
# 16/16 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1093 - val_accuracy: 1.0000 - val_loss: 0.1054
# Epoch 60/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.1082 - val_accuracy: 1.0000 - val_loss: 0.1045
# Epoch 61/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.1085 - val_accuracy: 1.0000 - val_loss: 0.1048
# Epoch 62/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.1069 - val_accuracy: 1.0000 - val_loss: 0.1032
# Epoch 63/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.1067 - val_accuracy: 1.0000 - val_loss: 0.1023
# Epoch 64/200
# 16/16 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1059 - val_accuracy: 1.0000 - val_loss: 0.1017
# Epoch 65/200
# 16/16 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1047 - val_accuracy: 1.0000 - val_loss: 0.1011
# Epoch 66/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.1040 - val_accuracy: 1.0000 - val_loss: 0.0999
# Epoch 67/200
# 16/16 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1035 - val_accuracy: 1.0000 - val_loss: 0.0996
# Epoch 68/200
# 16/16 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1029 - val_accuracy: 1.0000 - val_loss: 0.0985
# Epoch 69/200
# 16/16 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.1025 - val_accuracy: 1.0000 - val_loss: 0.0983
# Epoch 70/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.1018 - val_accuracy: 1.0000 - val_loss: 0.0981
# Epoch 71/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.1006 - val_accuracy: 1.0000 - val_loss: 0.0966
# Epoch 72/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.1009 - val_accuracy: 1.0000 - val_loss: 0.0968
# Epoch 73/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0996 - val_accuracy: 1.0000 - val_loss: 0.0960
# Epoch 74/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0988 - val_accuracy: 1.0000 - val_loss: 0.0952
# Epoch 75/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0978 - val_accuracy: 1.0000 - val_loss: 0.0941
# Epoch 76/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0971 - val_accuracy: 1.0000 - val_loss: 0.0935
# Epoch 77/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0968 - val_accuracy: 1.0000 - val_loss: 0.0935
# Epoch 78/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0966 - val_accuracy: 1.0000 - val_loss: 0.0925
# Epoch 79/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0958 - val_accuracy: 1.0000 - val_loss: 0.0922
# Epoch 80/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0949 - val_accuracy: 1.0000 - val_loss: 0.0913
# Epoch 81/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0947 - val_accuracy: 1.0000 - val_loss: 0.0907
# Epoch 82/200
# 16/16 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0942 - val_accuracy: 1.0000 - val_loss: 0.0907
# Epoch 83/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0933 - val_accuracy: 1.0000 - val_loss: 0.0894
# Epoch 84/200
# 16/16 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0928 - val_accuracy: 1.0000 - val_loss: 0.0903
# Epoch 85/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0925 - val_accuracy: 1.0000 - val_loss: 0.0888
# Epoch 86/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0913 - val_accuracy: 1.0000 - val_loss: 0.0880
# Epoch 87/200
# 16/16 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0918 - val_accuracy: 1.0000 - val_loss: 0.0883
# Epoch 88/200
# 16/16 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0915 - val_accuracy: 1.0000 - val_loss: 0.0876
# Epoch 89/200
# 16/16 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0911 - val_accuracy: 1.0000 - val_loss: 0.0877
# Epoch 90/200
# 16/16 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0904 - val_accuracy: 1.0000 - val_loss: 0.0867
# Epoch 91/200
# 16/16 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0892 - val_accuracy: 1.0000 - val_loss: 0.0856
# Epoch 92/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0887 - val_accuracy: 1.0000 - val_loss: 0.0851
# Epoch 93/200
# 16/16 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0878 - val_accuracy: 1.0000 - val_loss: 0.0842
# Epoch 94/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0875 - val_accuracy: 1.0000 - val_loss: 0.0856
# Epoch 95/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0885 - val_accuracy: 1.0000 - val_loss: 0.0846
# Epoch 96/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0875 - val_accuracy: 1.0000 - val_loss: 0.0834
# Epoch 97/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0866 - val_accuracy: 1.0000 - val_loss: 0.0832
# Epoch 98/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0860 - val_accuracy: 1.0000 - val_loss: 0.0827
# Epoch 99/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0853 - val_accuracy: 1.0000 - val_loss: 0.0820
# Epoch 100/200
# 16/16 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0854 - val_accuracy: 1.0000 - val_loss: 0.0817
# Epoch 101/200
# 16/16 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0844 - val_accuracy: 1.0000 - val_loss: 0.0820
# Epoch 102/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0845 - val_accuracy: 1.0000 - val_loss: 0.0814
# Epoch 103/200
# 16/16 - 0s - 10ms/step - accuracy: 1.0000 - loss: 0.0838 - val_accuracy: 1.0000 - val_loss: 0.0818
# Epoch 104/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0841 - val_accuracy: 1.0000 - val_loss: 0.0805
# Epoch 105/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.0837 - val_accuracy: 1.0000 - val_loss: 0.0801
# Epoch 106/200
# 16/16 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0833 - val_accuracy: 1.0000 - val_loss: 0.0793
# Epoch 107/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0822 - val_accuracy: 1.0000 - val_loss: 0.0794
# Epoch 108/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0818 - val_accuracy: 1.0000 - val_loss: 0.0787
# Epoch 109/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.0819 - val_accuracy: 1.0000 - val_loss: 0.0783
# Epoch 110/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0811 - val_accuracy: 1.0000 - val_loss: 0.0781
# Epoch 111/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0808 - val_accuracy: 1.0000 - val_loss: 0.0780
# Epoch 112/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0804 - val_accuracy: 1.0000 - val_loss: 0.0778
# Epoch 113/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0799 - val_accuracy: 1.0000 - val_loss: 0.0769
# Epoch 114/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0799 - val_accuracy: 1.0000 - val_loss: 0.0771
# Epoch 115/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0791 - val_accuracy: 1.0000 - val_loss: 0.0760
# Epoch 116/200
# 16/16 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0795 - val_accuracy: 1.0000 - val_loss: 0.0762
# Epoch 117/200
# 16/16 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.0793 - val_accuracy: 1.0000 - val_loss: 0.0754
# Epoch 118/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.0782 - val_accuracy: 1.0000 - val_loss: 0.0760
# Epoch 119/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0782 - val_accuracy: 1.0000 - val_loss: 0.0748
# Epoch 120/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0776 - val_accuracy: 1.0000 - val_loss: 0.0752
# Epoch 121/200
# 16/16 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0778 - val_accuracy: 1.0000 - val_loss: 0.0745
# Epoch 122/200
# 16/16 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0769 - val_accuracy: 1.0000 - val_loss: 0.0741
# Epoch 123/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0764 - val_accuracy: 1.0000 - val_loss: 0.0742
# Epoch 124/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0762 - val_accuracy: 1.0000 - val_loss: 0.0737
# Epoch 125/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0761 - val_accuracy: 1.0000 - val_loss: 0.0732
# Epoch 126/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0760 - val_accuracy: 1.0000 - val_loss: 0.0730
# Epoch 127/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0764 - val_accuracy: 1.0000 - val_loss: 0.0729
# Epoch 128/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0758 - val_accuracy: 1.0000 - val_loss: 0.0725
# Epoch 129/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0754 - val_accuracy: 1.0000 - val_loss: 0.0719
# Epoch 130/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0746 - val_accuracy: 1.0000 - val_loss: 0.0722
# Epoch 131/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0748 - val_accuracy: 1.0000 - val_loss: 0.0710
# Epoch 132/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0737 - val_accuracy: 1.0000 - val_loss: 0.0709
# Epoch 133/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0738 - val_accuracy: 1.0000 - val_loss: 0.0711
# Epoch 134/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0744 - val_accuracy: 1.0000 - val_loss: 0.0717
# Epoch 135/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0736 - val_accuracy: 1.0000 - val_loss: 0.0704
# Epoch 136/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0730 - val_accuracy: 1.0000 - val_loss: 0.0702
# Epoch 137/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0727 - val_accuracy: 1.0000 - val_loss: 0.0699
# Epoch 138/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.0728 - val_accuracy: 1.0000 - val_loss: 0.0696
# Epoch 139/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0723 - val_accuracy: 1.0000 - val_loss: 0.0691
# Epoch 140/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0718 - val_accuracy: 1.0000 - val_loss: 0.0690
# Epoch 141/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0725 - val_accuracy: 1.0000 - val_loss: 0.0709
# Epoch 142/200
# 16/16 - 0s - 16ms/step - accuracy: 1.0000 - loss: 0.0721 - val_accuracy: 1.0000 - val_loss: 0.0687
# Epoch 143/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.0709 - val_accuracy: 1.0000 - val_loss: 0.0684
# Epoch 144/200
# 16/16 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0705 - val_accuracy: 1.0000 - val_loss: 0.0676
# Epoch 145/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.0699 - val_accuracy: 1.0000 - val_loss: 0.0672
# Epoch 146/200
# 16/16 - 0s - 17ms/step - accuracy: 1.0000 - loss: 0.0696 - val_accuracy: 1.0000 - val_loss: 0.0667
# Epoch 147/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.0696 - val_accuracy: 1.0000 - val_loss: 0.0671
# Epoch 148/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.0692 - val_accuracy: 1.0000 - val_loss: 0.0667
# Epoch 149/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0697 - val_accuracy: 1.0000 - val_loss: 0.0682
# Epoch 150/200
# 16/16 - 0s - 21ms/step - accuracy: 1.0000 - loss: 0.0698 - val_accuracy: 1.0000 - val_loss: 0.0663
# Epoch 151/200
# 16/16 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0696 - val_accuracy: 1.0000 - val_loss: 0.0672
# Epoch 152/200
# 16/16 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0695 - val_accuracy: 1.0000 - val_loss: 0.0662
# Epoch 153/200
# 16/16 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0687 - val_accuracy: 1.0000 - val_loss: 0.0658
# Epoch 154/200
# 16/16 - 0s - 15ms/step - accuracy: 1.0000 - loss: 0.0686 - val_accuracy: 1.0000 - val_loss: 0.0660
# Epoch 155/200
# 16/16 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0678 - val_accuracy: 1.0000 - val_loss: 0.0661
# Epoch 156/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.0678 - val_accuracy: 1.0000 - val_loss: 0.0646
# Epoch 157/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.0677 - val_accuracy: 1.0000 - val_loss: 0.0647
# Epoch 158/200
# 16/16 - 0s - 14ms/step - accuracy: 1.0000 - loss: 0.0672 - val_accuracy: 1.0000 - val_loss: 0.0640
# Epoch 159/200
# 16/16 - 0s - 13ms/step - accuracy: 1.0000 - loss: 0.0665 - val_accuracy: 1.0000 - val_loss: 0.0637
# Epoch 160/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0668 - val_accuracy: 1.0000 - val_loss: 0.0640
# Epoch 161/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0662 - val_accuracy: 1.0000 - val_loss: 0.0633
# Epoch 162/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0664 - val_accuracy: 1.0000 - val_loss: 0.0642
# Epoch 163/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0657 - val_accuracy: 1.0000 - val_loss: 0.0635
# Epoch 164/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0658 - val_accuracy: 1.0000 - val_loss: 0.0633
# Epoch 165/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0655 - val_accuracy: 1.0000 - val_loss: 0.0636
# Epoch 166/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0654 - val_accuracy: 1.0000 - val_loss: 0.0628
# Epoch 167/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0650 - val_accuracy: 1.0000 - val_loss: 0.0617
# Epoch 168/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0649 - val_accuracy: 1.0000 - val_loss: 0.0623
# Epoch 169/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0649 - val_accuracy: 1.0000 - val_loss: 0.0625
# Epoch 170/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0648 - val_accuracy: 1.0000 - val_loss: 0.0626
# Epoch 171/200
# 16/16 - 0s - 12ms/step - accuracy: 1.0000 - loss: 0.0641 - val_accuracy: 1.0000 - val_loss: 0.0618
# Epoch 172/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0640 - val_accuracy: 1.0000 - val_loss: 0.0612
# Epoch 173/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0640 - val_accuracy: 1.0000 - val_loss: 0.0616
# Epoch 174/200
# 16/16 - 0s - 11ms/step - accuracy: 1.0000 - loss: 0.0642 - val_accuracy: 1.0000 - val_loss: 0.0609

# %%
def predecir_emocion(texto, umbrales_clase=None):
    # Limpieza
    texto_limpio = limpiar_texto(texto)
    
    # Vectorización
    texto_vec = vectorizer.transform([texto_limpio])
    
    # Normalización
    texto_norm = normalizer.transform(texto_vec.toarray())
    
    # Predicción
    prediccion = model.predict(texto_norm, verbose=0)[0]
    clase_predicha = np.argmax(prediccion)
    confianza = prediccion[clase_predicha]
    
    # Umbrales dinámicos (ejemplo)
    if umbrales_clase is None:
        umbrales_clase = {
            "tristeza": 0.6,
            "ansiedad": 0.65,
            "estrés": 0.55,
            "enojo": 0.7,
            "felicidad": 0.6
        }
    
    nombre_clase = label_encoder.inverse_transform([clase_predicha])[0]
    umbral = umbrales_clase.get(nombre_clase, 0.65)
    
    return (nombre_clase, confianza) if confianza >= umbral else ("indefinido", confianza)

# %%
def chatbot_respuesta(texto):
    emocion, confianza = predecir_emocion(texto)
    
    recursos = {
        "tristeza": {
            "mensaje": "🔵 Pareces sentir tristeza. Te recomiendo:",
            "acciones": [
                "Meditación guiada 'Alivio emocional' (10 min)",
                "Ejercicio: Escribe una carta para liberar emociones"
            ]
        },
        "ansiedad": {
            "mensaje": "🟠 Detecto señales de ansiedad. Prueba:",
            "acciones": [
                "Técnica de respiración 4-7-8 (instrucciones)",
                "Ejercicio de grounding: 5-4-3-2-1"
            ]
        },
        "estrés": {
            "mensaje": "🟢 Sugerencias para manejar el estrés:",
            "acciones": [
                "Meditación 'Libera tensiones' (15 min)",
                "Prioriza tareas con matriz Eisenhower"
            ]
        },
        "enojo": {
            "mensaje": "🔴 Detecto frustración. Intenta:",
            "acciones": [
                "Ejercicio físico de alta intensidad",
                "Técnica de pausa consciente de 5 minutos"
            ]
        },
        "felicidad": {
            "mensaje": "🟡 ¡Me alegra verte así! Mantén esto:",
            "acciones": [
                "Registra este momento en tu diario positivo",
                "Comparte tu estado con alguien especial"
            ]
        },
        "indefinido": {
            "mensaje": "⚪️ Necesito entenderte mejor. ¿Podrías:",
            "acciones": [
                "Describir cómo te sientes con más detalle?",
                "Contarme qué ha pasado recientemente?"
            ]
        }
    }
    
    respuesta = recursos.get(emocion, recursos["indefinido"])
    return (
        f"{respuesta['mensaje']}\n" + 
        "\n".join([f"- {accion}" for accion in respuesta['acciones']]) + 
        f"\n\nConfianza del modelo: {confianza:.2%}"
    )

# %%
test_cases = [
    "No tengo energía para nada hoy",
    "¡Acabo de conseguir el trabajo de mis sueños!",
    "Estoy harto de las injusticias en el trabajo",
    "Me siento mareado y con dificultad para respirar",
    "No sé qué me pasa, todo me parece gris"
]

for caso in test_cases:
    print(f"🧑 Usuario: {caso}")
    print(f"🤖 Chatbot:\n{chatbot_respuesta(caso)}\n")
    print("―" * 50)
# Out:
# 🧑 Usuario: No tengo energía para nada hoy
# 🤖 Chatbot:
# ⚪️ Necesito entenderte mejor. ¿Podrías:
# - Describir cómo te sientes con más detalle?
# - Contarme qué ha pasado recientemente?
#
# Confianza del modelo: 47.55%
#
# ――――――――――――――――――――――――――――――――――――――――――――――――――
# 🧑 Usuario: ¡Acabo de conseguir el trabajo de mis sueños!
# 🤖 Chatbot:
# 🟢 Sugerencias para manejar el estrés:
# - Meditación 'Libera tensiones' (15 min)
# - Prioriza tareas con matriz Eisenhower
#
# Confianza del modelo: 68.00%
#
# ――――――――――――――――――――――――――――――――――――――――――――――――――
# 🧑 Usuario: Estoy harto de las injusticias en el trabajo
# 🤖 Chatbot:
# 🟢 Sugerencias para manejar el estrés:
# - Meditación 'Libera tensiones' (15 min)
# - Prioriza tareas con matriz Eisenhower
#
# Confianza del modelo: 68.00%
#
# ――――――――――――――――――――――――――――――――――――――――――――――――――
# 🧑 Usuario: Me siento mareado y con dificultad para respirar
# 🤖 Chatbot:
# 🔵 Pareces sentir tristeza. Te recomiendo:
# - Meditación guiada 'Alivio emocional' (10 min)
# - Ejercicio: Escribe una carta para liberar emociones
#
# Confianza del modelo: 64.18%
#
# ――――――――――――――――――――――――――――――――――――――――――――――――――
# 🧑 Usuario: No sé qué me pasa, todo me parece gris
# 🤖 Chatbot:
# ⚪️ Necesito entenderte mejor. ¿Podrías:
# - Describir cómo te sientes con más detalle?
# - Contarme qué ha pasado recientemente?
#
# Confianza del modelo: 27.84%
#
# ――――――――――――――――――――――――――――――――――――――――――――――――――
